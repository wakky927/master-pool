# %%
import pickle

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from tqdm import tqdm

# %%
import warnings
warnings.simplefilter("ignore", UserWarning)

# %%
IN_DIR = "D:\\result\\20221027\\"
OUT_DIR = "D:\\result\\20221027\\"
sub_dir_list = "rbi_q_30\\2\\"

# %%
time_table = pd.read_csv("time.csv", header=None, index_col=0)
time_table = time_table.values[8, :36].astype(np.int)

# %%
ptv_result = np.zeros((1, 4))

# %%
for t in range(1, 11):
    for i in tqdm(range(t, 10900, 10)):
        for j in range(17):
            if time_table[2 * j] <= i < time_table[2 * j + 1]:
                try:
                    r = np.loadtxt(OUT_DIR + "ptv\\" + sub_dir_list + f"pp_{i}.csv", delimiter=',', skiprows=1)
                except StopIteration:
                    r = None
                except OSError:
                    r = None

                if r is None:
                    pass
                elif r.ndim == 1:
                    if len(r) > 0:
                        r = r[np.newaxis, :]
                        ptv_result = np.vstack([ptv_result, r])

                elif r.ndim == 2:
                    ptv_result = np.vstack([ptv_result, r])
# Out:
# 100%|██████████| 1090/1090 [00:01<00:00, 734.50it/s]
# 100%|██████████| 1090/1090 [00:02<00:00, 438.58it/s]
# 100%|██████████| 1090/1090 [00:03<00:00, 307.61it/s]
# 100%|██████████| 1090/1090 [00:04<00:00, 228.60it/s]
# 100%|██████████| 1090/1090 [00:06<00:00, 166.33it/s]
# 100%|██████████| 1090/1090 [00:08<00:00, 131.51it/s]
# 100%|██████████| 1090/1090 [00:09<00:00, 116.41it/s]
# 100%|██████████| 1090/1090 [00:09<00:00, 112.10it/s]
# 100%|██████████| 1090/1090 [00:10<00:00, 108.05it/s]
# 100%|██████████| 1089/1089 [00:10<00:00, 106.37it/s]

# %%
ptv_result = pd.DataFrame(ptv_result, columns=['x', 'y', 'dx', 'dy'])
for row in ptv_result.index:
    if (ptv_result.loc[row] == 0).all():
        ptv_result.drop(row, axis=0, inplace=True)

# %%
ptv_result['x'] = ptv_result['x'] - 498
ptv_result['y'] = 51 - ptv_result['y']
ptv_result['dy'] = - ptv_result['dy']

# %%
ptv_result['dr'] = np.sqrt(ptv_result['dx']**2 + ptv_result['dy']**2)

# %%
fig, ax = plt.subplots(figsize=(20, 12))
plt.xlim(-512, 512)
plt.ylim(-500, 100)
c = ax.quiver(ptv_result['x'], ptv_result['y'], ptv_result['dx'], ptv_result['dy'], ptv_result['dr'], cmap="jet")
fig.colorbar(c)
plt.show()

# %%
with open(f'ptv_rbi_q_30_2.pickle', mode='wb') as fp:
    pickle.dump(ptv_result, fp)
